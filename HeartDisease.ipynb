# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tag=pd.read_csv("TAG.csv")
tsgene=pd.read_csv("TSGENE.csv")
cosmic=pd.read_csv("COSMIC.csv")

# %%
tag.head()
# Out:
#    CNO     START       END      CYTOBAND    GSYM     GTYPE  \
# 0    1         0   2300000       1p36.33     SKI  Oncogene
# 1    1   7100000   9200000       1p36.23   PARK7  Oncogene
# 2    1   7100000  27800000  1p36.2-p36.1     FGR  Oncogene
# 3    1   7100000  16100000        1p36.2    ENO1        --
# 4    1  16100000  20300000       1p36.13  AKR7A2     Other
#
#                                              DISEASE
# 0         V-Ski Avian Sarcoma Viral Oncogene Homolog
# 1                                Parkinson Protein 7
# 2  Feline Gardner-Rasheed Sarcoma Viral Oncogene ...
# 3                                          enolase 1
# 4                       Aldo-Keto Reductase Family 7

# %%
tag.tail()
# Out:
#      CNO     START       END CYTOBAND       GSYM                  GTYPE  \
# 763   22  35900000  39300000  22q13.1      PDGFB               Oncogene
# 764   22  35900000  39300000  22q13.1      SSTR3                  Other
# 765   22  39300000  42600000  22q13.2       RBX1  Tumor suppressor gene
# 766   22  39300000  42600000  22q13.2       ST13  Tumor suppressor gene
# 767   22  42600000  49691432  22q13.3  LINC00229                     --
#
#                                                DISEASE
# 763    Platelet-Derived Growth Factor Beta Polypeptide
# 764                            Somatostatin Receptor 3
# 765                                         Ring-Box 1
# 766  Suppression Of Tumorigenicity 13 (Colon Carcin...
# 767  long intergenic non-protein coding RNA 229 (Pr...

# %%
tag.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CNO       768 non-null    int64
#  1   START     768 non-null    int64
#  2   END       768 non-null    int64
#  3   CYTOBAND  768 non-null    object
#  4   GSYM      768 non-null    object
#  5   GTYPE     768 non-null    object
#  6   DISEASE   768 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 30.1+ KB

# %%
tag.describe()
# Out:
#               CNO         START           END
# count  768.000000  7.680000e+02  7.680000e+02
# mean     9.397135  7.051927e+07  7.866678e+07
# std      6.258019  5.478979e+07  5.549992e+07
# min      1.000000  0.000000e+00  2.300000e+06
# 25%      4.000000  2.837500e+07  3.540000e+07
# 50%      9.000000  5.550000e+07  6.291798e+07
# 75%     14.000000  1.072000e+08  1.154000e+08
# max     22.000000  2.417000e+08  2.472497e+08

# %%
tag.isnull().sum()
# Out:
# CNO         0
# START       0
# END         0
# CYTOBAND    0
# GSYM        0
# GTYPE       0
# DISEASE     0
# dtype: int64

# %%
tag['CNO'].plot.hist()

# %%
tag['START'].plot.hist()

# %%
tag['END'].plot.hist()

# %%
tag['GSYM'].value_counts()
# Out:
# TGM3         2
# CEBPD        2
# JUND         1
# CTBP1        1
# ERBB2        1
#             ..
# CYLD         1
# FGF10-AS1    1
# PLCD1        1
# LGALS8       1
# KRIT1        1
# Name: GSYM, Length: 766, dtype: int64

# %%
tag['CYTOBAND'].value_counts()
# Out:
# 11q13          11
# 11p15.5        10
# 3p21.3          9
# 1q21            9
# 17p13.3         7
#                ..
# 12q22-q23       1
# 3p26            1
# 19q13.4         1
# 11p15.3-p14     1
# 11q13.2         1
# Name: CYTOBAND, Length: 468, dtype: int64

# %%
tag['DISEASE'].value_counts()
# Out:
# Protein Tyrosine Phosphatase                                     10
# Myeloid/Lymphoid Or Mixed-Lineage Leukemia (Trithorax Homolog     5
# Collagen                                                          4
# Inhibitor Of Growth Family                                        4
# Wingless-Type MMTV Integration Site Family                        4
#                                                                  ..
# PTK6 protein tyrosine kinase 6 PTK6: Approved                     1
# WW Domain Containing Oxidoreductase                               1
# V-Yes-1 Yamaguchi Sarcoma Viral Related Oncogene Homolog          1
# Dopamine Receptor D4                                              1
# BTB And CNC Homology 1                                            1
# Name: DISEASE, Length: 705, dtype: int64

# %%
tag.plot.scatter(x ='DISEASE', y ='CNO', rot =90,figsize=(10, 10))

# %%
tag.plot.scatter(x ='DISEASE', y ='GTYPE', rot =90,figsize=(10, 10))

# %%
tag['GTYPE'].value_counts()
# Out:
# Tumor suppressor gene                 232
# Oncogene                              218
# --                                    150
# Other                                 142
# & -- & Oncogene                         9
# & -- & Tumor suppressor gene            6
# & Oncogene & Tumor suppressor gene      3
# & Tumor suppressor gene & --            3
# & -- & Other                            2
# & Oncogene & --                         1
# & -- & oncogene                         1
# & Other & Tumor suppressor gene         1
# Name: GTYPE, dtype: int64

# %%
tag.plot.scatter(x ='GTYPE', y ='CNO', rot =90,figsize=(10, 10))

# %%
tag.plot.scatter(x ='GTYPE', y ='START', rot =90,figsize=(10, 10))

# %%
tag.plot.scatter(x ='GTYPE', y ='END', rot =90,figsize=(10, 10))

# %%
tag.plot.scatter(x ='START', y ='END', rot =90,figsize=(10, 10))

# %%
tsgene.head()
# Out:
#                               ID CNO     START       END Unnamed: 4  \
# 0  20:054400000:062435964:tsg001  20  54400000  62435964    20q13.3
# 1  03:044700000:051400000:tsg002   3  44700000  51400000    3p21.31
# 2  11:000000000:002800000:tsg003  11         0   2800000    11p15.5
# 3  11:000000000:002800000:tsg004  11         0   2800000    11p15.5
# 4  16:056700000:065200000:tsg005  16  56700000  65200000      16q21
#
#    Unnamed: 5     GSYM                  GNAME  \
# 0        1002     CDH4              CAD4|RCAD
# 1   100302232  MIR1226  MIRN1226|hsa-mir-1226
# 2       10077  TSPAN32  ART1|PHEMX|PHMX|TSSC6
# 3       10078    TSSC4                      -
# 4        1009    CDH11   CAD11|CDHOB|OB|OSF-4
#
#                                           Unnamed: 8  \
# 0  HGNC:1763|MIM:603006|Ensembl:ENSG00000179242|H...
# 1                       HGNC:33922|miRBase:MI0006313
# 2  HGNC:13410|MIM:603853|Ensembl:ENSG00000064201|...
# 3  HGNC:12386|MIM:603852|Ensembl:ENSG00000184281|...
# ...

# %%
tsgene.tail()
# Out:
#                                 ID CNO      START        END     Unnamed: 4  \
# 709  09:019900000:032800000:tsg710   9   19900000   32800000           9p21
# 710  20:027100000:037100000:tsg711  20   27100000   37100000          20q11
# 711  11:000000000:002800000:tsg712  11          0    2800000        11p15.5
# 712  19:047800000:063811651:tsg713  19   47800000   63811651  19q13.3-q13.4
# 713  01:171200000:174300000:tsg714   1  171200000  174300000         1q25.1
#
#      Unnamed: 5    GSYM                                              GNAME  \
# 709       11191  PTENP1                         PTEN-rs|PTEN2|PTH2|psiPTEN
# 710      171023   ASXL1                                           BOPS|MDS
# 711      283120     H19  ASM|ASM1|BWS|D11S813E|LINC00008|NCRNA00008|PRO...
# 712         581     BAX                                             BCL2L4
# 713       60674    GAS5                                   NCRNA00030|SNHG2
#
#                                             Unnamed: 8  \
# ...

# %%
tsgene.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           714 non-null    object
#  1   CNO          714 non-null    object
#  2   START        714 non-null    int64
#  3   END          714 non-null    int64
#  4   Unnamed: 4   714 non-null    object
#  5   Unnamed: 5   714 non-null    int64
#  6   GSYM         714 non-null    object
#  7   GNAME        714 non-null    object
#  8   Unnamed: 8   714 non-null    object
#  9   Unnamed: 9   714 non-null    object
#  10  Unnamed: 10  714 non-null    object
#  11  GPATTERN     714 non-null    object
# dtypes: int64(3), object(9)
# memory usage: 41.9+ KB

# %%
tsgene.describe()
# Out:
#               START           END    Unnamed: 5
# count  7.140000e+02  7.140000e+02  7.140000e+02
# mean   6.891457e+07  7.674087e+07  2.097216e+05
# std    5.536436e+07  5.582424e+07  3.753375e+06
# min    0.000000e+00  2.200000e+06  1.410000e+02
# 25%    2.430000e+07  3.280000e+07  4.765000e+03
# 50%    5.240000e+07  6.100000e+07  9.033500e+03
# 75%    1.067250e+08  1.139000e+08  5.693625e+04
# max    2.417000e+08  2.472497e+08  1.003022e+08

# %%
tsgene.isnull().sum()
# Out:
# ID             0
# CNO            0
# START          0
# END            0
# Unnamed: 4     0
# Unnamed: 5     0
# GSYM           0
# GNAME          0
# Unnamed: 8     0
# Unnamed: 9     0
# Unnamed: 10    0
# GPATTERN       0
# dtype: int64

# %%
tsgene['START'].plot.hist()

# %%
tsgene['Unnamed: 5'].plot.hist()

# %%
tsgene['END'].plot.hist()

# %%
tsgene['GSYM'].value_counts()
# Out:
# MIR127     1
# CDC73      1
# PTPRK      1
# S100A11    1
# STAT5A     1
#           ..
# BAI2       1
# PCDH10     1
# GSTT1      1
# MIR200A    1
# ZBTB16     1
# Name: GSYM, Length: 714, dtype: int64

# %%
tsgene['GNAME'].value_counts()
# Out:
# -                                                                          52
# GPR12A|OGR1                                                                 1
# CAR|DLEU5|LEU5|RFP2|RNF77                                                   1
# HAP|NR1B2|RRB2                                                              1
# AWT1|EWS-WT1|GUD|NPHS4|WAGR|WIT-2|WT33                                      1
#                                                                            ..
# MIR17-5p|MIR91|MIRN17|MIRN91|hsa-mir-17|miR-17|miR17-3p|miRNA17|miRNA91     1
# PBP|Pc-1|TRPP1                                                              1
# 4.1B|DAL-1|DAL1                                                             1
# DMP1|DMTF|hDMP1                                                             1
# CABL1|CABLES|HsT2563|IK3-1                                                  1
# Name: GNAME, Length: 663, dtype: int64

# %%
tsgene['GPATTERN'].value_counts()
# Out:
# -                                                                                                                                                                                                            86
# CCN family member 2|IBP-8|IGF-binding protein 8|IGFBP-8|hypertrophic chondrocyte-specific protein 24|insulin-like growth factor-binding protein 8                                                             1
# E3 ubiquitin-protein ligase HACE1|HECT domain and ankyrin repeat-containing E3 ubiquitin-protein ligase 1                                                                                                     1
# 14-3-3 protein sigma|14-3-3 sigma|epithelial cell marker protein 1                                                                                                                                            1
# ...

# %%
tsgene['Unnamed: 10'].value_counts()
# Out:
# protein-coding    636
# miscRNA            76
# snoRNA              1
# pseudo              1
# Name: Unnamed: 10, dtype: int64

# %%
tsgene.plot.scatter(x ='Unnamed: 10', y ='START', rot =90,figsize=(10, 10))

# %%
tsgene.plot.scatter(x ='Unnamed: 10', y ='Unnamed: 5', rot =90,figsize=(5, 5))

# %%
tsgene.plot.scatter(x ='GPATTERN', y ='Unnamed: 10', rot =90,figsize=(10, 10))

# %%
tsgene['Unnamed: 9'].value_counts()
# Out:
# exostoses (multiple)-like 1                                 1
# protein phosphatase 2A activator, regulatory subunit 4      1
# family with sequence similarity 188, member A               1
# StAR-related lipid transfer (START) domain containing 13    1
# ribosomal protein L10                                       1
#                                                            ..
# microRNA 124-1                                              1
# N-acetyltransferase 6 (GCN5-related)                        1
# von Willebrand factor A domain containing 5A                1
# polycystic kidney disease 1 (autosomal dominant)            1
# synemin, intermediate filament protein                      1
# Name: Unnamed: 9, Length: 714, dtype: int64

# %%
tsgene['Unnamed: 8'].value_counts()
# Out:
# HGNC:9165|MIM:603696|Ensembl:ENSG00000108387|HPRD:04738                             1
# HGNC:6349|MIM:602903|Ensembl:ENSG00000102554|HPRD:04212|Vega:OTTHUMG00000017074     1
# HGNC:31500|MIM:610252|miRBase:MI0000437                                             1
# HGNC:19127|MIM:607862|Ensembl:ENSG00000176490|HPRD:09710                            1
# HGNC:31636|MIM:611374|miRBase:MI0000742                                             1
#                                                                                    ..
# HGNC:3393|MIM:600997|Ensembl:ENSG00000133216|HPRD:02997|Vega:OTTHUMG00000002881     1
# HGNC:10886|MIM:604480|Ensembl:ENSG00000068903|HPRD:10377|Vega:OTTHUMG00000150480    1
# HGNC:31484|MIM:300721|miRBase:MI0000068                                             1
# HGNC:6954|MIM:607117|Ensembl:ENSG00000147316|HPRD:06174|Vega:OTTHUMG00000163618     1
# HGNC:10520|MIM:602895|Ensembl:ENSG00000160633|HPRD:04205                            1
# ...

# %%
tsgene['Unnamed: 4'].value_counts()
# Out:
# 3p21.3      14
# 17p13.3      8
# 19p13.3      7
# 8p22         7
# 11p15.5      7
#             ..
# 10q11.21     1
# 4q35         1
# 3q26.3       1
# 1p36.13      1
# 19q13.31     1
# Name: Unnamed: 4, Length: 462, dtype: int64

# %%
tsgene.plot.scatter(x ='Unnamed: 4', y ='START', rot =90,figsize=(10, 10))

# %%
cosmic.head()
# Out:
#                                 ID  CNO  START        END  Unnamed: 4  \
# 0  01:000047851:000727088:cos00001    1  47851     727088     1653152
# 1  01:000061735:002545650:cos00002    1  61735    2545650     1474936
# 2  01:000061735:004286684:cos00003    1  61735    4286684     1475001
# 3  01:000061735:008347361:cos00004    1  61735    8347361     1651056
# 4  01:000061735:121482979:cos00005    1  61735  121482979     1651312
#
#    Unnamed: 5       Unnamed: 6 Unnamed: 7 Unnamed: 8        Unnamed: 9  \
# 0     1567939         pancreas         NS  carcinoma                NS
# 1     1398635            ovary         NS  carcinoma  serous_carcinoma
# 2     1398700            ovary         NS  carcinoma  serous_carcinoma
# 3     1565843  large_intestine      colon  carcinoma    adenocarcinoma
# 4     1566099  large_intestine      colon  carcinoma    adenocarcinoma
#
#    Unnamed: 10  Unnamed: 11 Unnamed: 12
# 0          2.0          NaN         NaN
# ...

# %%
cosmic.tail()
# Out:
#                                     ID  CNO     START       END  Unnamed: 4  \
# 65530  24:022889018:028699018:cos65531   24  22889018  28699018     1653090
# 65531  24:023241047:028699018:cos65532   24  23241047  28699018     1653101
# 65532  24:023241047:028699018:cos65533   24  23241047  28699018     1653107
# 65533  24:023984056:028699018:cos65534   24  23984056  28699018     1653053
# 65534  24:023984056:028699018:cos65535   24  23984056  28699018     1653102
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# 65530     1567877   pancreas         NS  carcinoma         NS          0.0
# 65531     1567888   pancreas         NS  carcinoma         NS          3.0
# 65532     1567894   pancreas         NS  carcinoma         NS          2.0
# 65533     1567840   pancreas         NS  carcinoma         NS          1.0
# 65534     1567889   pancreas         NS  carcinoma         NS          0.0
#
#        Unnamed: 11 Unnamed: 12
# ...

# %%
cosmic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65535 entries, 0 to 65534
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           65535 non-null  object
#  1   CNO          65535 non-null  int64
#  2   START        65535 non-null  int64
#  3   END          65535 non-null  int64
#  4   Unnamed: 4   65535 non-null  int64
#  5   Unnamed: 5   65535 non-null  int64
#  6   Unnamed: 6   65535 non-null  object
#  7   Unnamed: 7   65535 non-null  object
#  8   Unnamed: 8   65535 non-null  object
#  9   Unnamed: 9   65535 non-null  object
#  10  Unnamed: 10  65467 non-null  float64
#  11  Unnamed: 11  36888 non-null  float64
#  12  Unnamed: 12  36756 non-null  object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 5.0+ MB

# %%
cosmic.describe()
# Out:
#                 CNO         START           END    Unnamed: 4    Unnamed: 5  \
# count  65535.000000  6.553500e+04  6.553500e+04  6.553500e+04  6.553500e+04
# mean       9.693675  7.336414e+07  7.525040e+07  1.661114e+06  1.573825e+06
# std        6.322296  5.519619e+07  5.535127e+07  9.615971e+04  9.155624e+04
# min        1.000000  1.000000e+00  1.570300e+04  1.184078e+06  1.096043e+06
# 25%        4.000000  2.905164e+07  3.066826e+07  1.651532e+06  1.566318e+06
# 50%        8.000000  6.034946e+07  6.224923e+07  1.653101e+06  1.567888e+06
# 75%       14.000000  1.107811e+08  1.129218e+08  1.731257e+06  1.637223e+06
# max       24.000000  2.492026e+08  2.492284e+08  1.783457e+06  1.687456e+06
#
#         Unnamed: 10   Unnamed: 11
# count  65467.000000  36888.000000
# mean       5.181799      1.352418
# std        6.646514      1.678827
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        3.000000      1.000000
# 75%        8.000000      2.000000
# ...

# %%
cosmic.isnull().sum()
# Out:
# ID                 0
# CNO                0
# START              0
# END                0
# Unnamed: 4         0
# Unnamed: 5         0
# Unnamed: 6         0
# Unnamed: 7         0
# Unnamed: 8         0
# Unnamed: 9         0
# Unnamed: 10       68
# Unnamed: 11    28647
# Unnamed: 12    28779
# dtype: int64

# %%
cosmic['CNO'].plot.hist()

# %%
cosmic['Unnamed: 5'].plot.hist()

# %%
cosmic['Unnamed: 4'].plot.hist()

# %%
cosmic['Unnamed: 10'].plot.hist()

# %%
cosmic['Unnamed: 11'].plot.hist()

# %%
cosmic['Unnamed: 6'].value_counts()
# Out:
# pancreas                              28323
# large_intestine                       10038
# ovary                                  9162
# lung                                   7597
# breast                                 3083
# endometrium                            2226
# haematopoietic_and_lymphoid_tissue     1465
# kidney                                 1193
# central_nervous_system                  910
# urinary_tract                           879
# liver                                   256
# cervix                                  236
# NS                                      167
# Name: Unnamed: 6, dtype: int64

# %%
cosmic['Unnamed: 7'].value_counts()
# Out:
# NS         53722
# colon       5972
# rectum      3041
# caecum      1011
# brain        910
# bladder      879
# Name: Unnamed: 7, dtype: int64

# %%
cosmic['Unnamed: 8'].value_counts()
# Out:
# carcinoma                                           62920
# haematopoietic_neoplasm                              1454
# glioma                                                875
# NS                                                    240
# primitive_neuroectodermal_tumour-medulloblastoma       35
# lymphoid_neoplasm                                      11
# Name: Unnamed: 8, dtype: int64

# %%
cosmic['Unnamed: 9'].value_counts()
# Out:
# NS                                                          32376
# adenocarcinoma                                              13214
# serous_carcinoma                                             9162
# squamous_cell_carcinoma                                      4584
# endometrioid_carcinoma                                       2226
# acute_myeloid_leukaemia                                      1454
# clear_cell_renal_cell_carcinoma                              1193
# astrocytoma_Grade_IV                                          875
# hepatocellular_carcinoma                                      256
# ductal_carcinoma                                              149
# large_cell                                                     35
# chronic_lymphocytic_leukaemia-small_lymphocytic_lymphoma       11
# Name: Unnamed: 9, dtype: int64

# %%
cosmic['Unnamed: 12'].value_counts()
# Out:
# GAIN    23280
# LOSS    13476
# Name: Unnamed: 12, dtype: int64

# %%
cosmic.plot.scatter(x ='Unnamed: 6', y ='Unnamed: 7', rot =90,figsize=(5, 5))

# %%
cosmic.plot.scatter(x ='Unnamed: 6', y ='Unnamed: 8', rot =90,figsize=(5, 5))

# %%
cosmic.plot.scatter(x ='Unnamed: 6', y ='Unnamed: 9', rot =90,figsize=(5, 5))

# %%
cosmic.plot.scatter(x ='Unnamed: 7', y ='Unnamed: 8', rot =90,figsize=(5, 5))

# %%
cosmic.plot.scatter(x ='Unnamed: 7', y ='Unnamed: 9', rot =90,figsize=(5, 5))

# %%
cosmic.plot.scatter(x ='Unnamed: 8', y ='Unnamed: 9', rot =90,figsize=(5, 5))

# %%
cosmic.plot.scatter(x ='CNO', y ='Unnamed: 6', rot =90,figsize=(5, 5))

# %%
cosmic.plot.scatter(x ='Unnamed: 4', y ='Unnamed: 6', rot =90,figsize=(5, 5))

# %%
cosmic.plot.scatter(x ='Unnamed: 5', y ='Unnamed: 7', rot =90,figsize=(5, 5))
